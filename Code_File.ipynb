# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow import keras


# import keras
# from keras.layers import Dense

#  Import and read the charity_data.csv.
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       4 import pandas as pd
#       5 import tensorflow as tf
# ----> 6 from tensorflow import keras
#       9 # import keras
#      10 # from keras.layers import Dense
#      11
#      12 #  Import and read the charity_data.csv.
#      13 application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
#
# ImportError: cannot import name 'keras' from 'tensorflow' (unknown location)

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns= ['EIN', 'NAME'], inplace= True)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_counts = application_df['APPLICATION_TYPE'].value_counts()
app_type_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_type_counts[app_type_counts < 1000].index)
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_vc = application_df['CLASSIFICATION'].value_counts()
classification_vc
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_vc[classification_vc> 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_vc[classification_vc<1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_to_dummies = pd.get_dummies(application_df)
boolean_cols = application_to_dummies.select_dtypes(include='bool').columns
application_to_dummies[boolean_cols] = application_to_dummies[boolean_cols].astype(int)
application_to_dummies
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       1
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                         0                    0                    0
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = application_to_dummies.drop(["IS_SUCCESSFUL"],axis=1)
y = application_to_dummies["IS_SUCCESSFUL"]

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %% [markdown]
# Model#1

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn1 = keras.models.Sequential()

# First hidden layer
nn1.add(keras.layers.Dense(units=80, input_dim=len(X_train_scaled[0]), activation="relu"))

# Second hidden layer
nn1.add(keras.layers.Dense(units=30, activation="tanh"))

# Output layer
nn1.add(keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn1.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 4
#       1 # Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#       2 #  YOUR CODE GOES HERE
# ----> 4 nn1 = tf.keras.models.Sequential()
#       6 # First hidden layer
#       7 nn1.add(tf.keras.layers.Dense(units=80, input_dim=len(X_train_scaled[0]), activation="relu"))
#
# AttributeError: module 'tensorflow' has no attribute 'keras'

# %%
# Compile the model
nn1.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Compile the model
# ----> 2 nn1.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
#
# NameError: name 'nn1' is not defined

# %%
# Train the model
nn1.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5729 - accuracy: 0.7162
# Epoch 2/100
# 804/804 [==============================] - 1s 991us/step - loss: 0.5593 - accuracy: 0.7268
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5558 - accuracy: 0.7287
# Epoch 4/100
# 804/804 [==============================] - 1s 961us/step - loss: 0.5546 - accuracy: 0.7303
# Epoch 5/100
# 804/804 [==============================] - 1s 959us/step - loss: 0.5532 - accuracy: 0.7285
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5524 - accuracy: 0.7302
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5512 - accuracy: 0.7301
# Epoch 8/100
# 804/804 [==============================] - 1s 975us/step - loss: 0.5510 - accuracy: 0.7314
# Epoch 9/100
# 804/804 [==============================] - 1s 948us/step - loss: 0.5502 - accuracy: 0.7324
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5582 - accuracy: 0.7305 - 291ms/epoch - 1ms/step
# Loss: 0.5581920146942139, Accuracy: 0.7304956316947937

# %%
# Export our model to HDF5 file
nn1.save('AlphabetSoupCharity1.h5')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Export our model to HDF5 file
# ----> 2 nn1.save('AlphabetSoupCharity1.h5')
#
# File c:\Users\malav\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\malav\anaconda3\lib\site-packages\keras\saving\hdf5_format.py:80, in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#      54 """Saves a model to a HDF5 file.
#      55
#      56 The saved model contains:
#    (...)
# ...

# %% [markdown]
# Model#2

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn2 = tf.keras.models.Sequential()

# First hidden layer
nn2.add(tf.keras.layers.Dense(units=120, input_dim=len(X_train_scaled[0]), activation="relu"))

# Second hidden layer
nn2.add(tf.keras.layers.Dense(units=80, activation="tanh"))

# Third hidden layer
nn2.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn2.summary()

# %%
# Compile the model
nn2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
nn2.fit(X_train_scaled,y_train,epochs=100)

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Export our model to HDF5 file
nn2.save('AlphabetSoupCharity2.h5')

# %% [markdown]
# Model#3

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn3 = tf.keras.models.Sequential()

# First hidden layer
nn3.add(tf.keras.layers.Dense(units=300, input_dim=len(X_train_scaled[0]), activation="relu"))

# Second hidden layer
nn3.add(tf.keras.layers.Dense(units=100, activation="tanh"))

# Third hidden layer
nn3.add(tf.keras.layers.Dense(units=50, activation="relu"))

# Fourth hidden layer
nn3.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn3.summary()

# %%
# Compile the model
nn3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
nn3.fit(X_train_scaled,y_train,epochs=100)

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Export our model to HDF5 file
nn3.save('AlphabetSoupCharity3.h5')
